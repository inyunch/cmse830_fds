# %% [markdown]
# # Homework 01: Surveys, Syllabus, and Reading
#
# ### <p style="text-align: right;"> &#9989; Yun Chen

# %% [markdown]
# Welcome to your first homework assignment! This assignment will help you set up the necessary tools and familiarize yourself with course materials essential for your success in this Data Science course.
#
# ## Objectives
# By completing this homework, you will:
#
# * Familiarize yourself with course expectations and policies
# * Set up essential tools for the course
# * Assess your current Python knowledge
# * Begin engaging with course content

# %% [markdown]
# ## Part 1. Read Course Materials (10 points)
#
# There are three important documents for this course. In this problem you will find them, read them and summarize them.
#
# 🗒️ **Task:** Read the course syllabus (available in Teams and D2L as a PDF). In a new markdown cell, summarize the portions of the syllabus regarding attendance and late assignments.

# %% [markdown]
# ✏️ **Answer**

# %% [markdown]
# Attendance is mandatory for this course, with unexcused absences resulting in zero points for the day. Students are permitted up to two excused absences, but these must be arranged with the professor beforehand for legitimate reasons. For late assignments, ICAs are not accepted late and will receive zero credit if not submitted on time with your group. Homework assignments, however, can be submitted for up to two days beyond the due date, incurring a 10% penalty within 24 hours and a 20% deduction between 24 and 48 hours. The final semester project cannot be submitted late.

# %% [markdown]
# 🗒️ **Task:** Read the AI policy (PDF). In a new markdown cell, summarize what you need to do to do when you use AI for an assignment.

# %% [markdown]
# ✏️ **Answer**

# %% [markdown]
# *  Avoid submitting work generated entirely by AI
# *  Provide proper attribution for all AI tools used
# *  Always consider AI output as potentially inaccurate, as we need to have our own critical thinking, creativity, and understanding of the course material
# *  Understand and explain every line of code or chart with coding assigment or data analysis and visualization tasks

# %% [markdown]
# 🗒️ **Task:** Read the AI guide to best practices (PDF). Also in a new markdown cell, give us some feedback on your experiences using AI in the past. How well did it work? What strategies have you developed for yourself, if any?

# %% [markdown]
# ✏️ **Answer**

# %% [markdown]
# According to my past experience in job experience, I have two crutial aspects. The first one is about improving the work efficiency. It can reduce communication time with others and  help me develop specific task like divid a project with a smooth steps by priority. The second one is for rewarding learning. When I learn new thing with AI tools, I can pick up it quickly in a correct track. Comparing to 10 years ago when I was in college, the learning way is changed a lot due to these AI tools, but I do believe those past experience in my brain will be valuable when combined with modern techonology.

# %% [markdown]
# ## Part 2. GitHub Setup (10 points)
#
# You will use GitHub for your two projects. In addition to learning an important data science tool, this will allow you to retain all of your work beyond this course and share with people around the world.
#
# 🗒️ **Task:**
# * Create a GitHub account (if you don't already have one)
# * If you are not already familiar with GH:
#   * [this](https://www.youtube.com/watch?v=tRZGeaHPoaw) is a great video - watch it slowly over the next week or so
#   * and, you can complete the GitHub Hello World guide: https://guides.github.com/activities/hello-world/
# * Create a new repository for this course and call it `cmse830_fds`
#
# In the markdown cell below add your github username and repo name.

# %% [markdown]
# ✏️ **Answer**

# %% [markdown]
# * username: inyunch
# * repo name: https://github.com/inyunch/cmse830_fds

# %% [markdown]
# ## Part 3. Initial and Python Surveys (10 points)
#
# Complete the [initial survey](https://forms.office.com/r/GNHk4SgyNg) _if you haven't already_.
#
# Complete the Python coding knowledge survey: [click here](https://forms.office.com/r/c9exRxM4aV)
#
# Put a statement in a markdown cell that you have completed both of these.

# %% [markdown]
# ✏️ **Answer**

# %% [markdown]
# I have completed both the initial survey and the Python coding knowledge survey.

# %% [markdown]
# ## Part 4. Textbook Reading (10 points)
#
# 🗒️ **Task:** Read Chapter 1 of "_Thinking Clearly with Data_"
# * In a markdown cell, give a very high-level overview of the book
#    * what are its goals and how are those goals organized?
#    * what can you hope to get out of this book?
# * Write a brief summary (200-300 words) of the key points from Chapter 1

# %% [markdown]
# ✏️ **Answer**

# %% [markdown]
# 1. The goal of the book is to help readers learn how to think in a data-driven way, guiding us step by step from understanding correlation and causation to making decisions based on information. I hope that I can get the way of thinking with quantitative data from observation the chart or learn how to use correct way to do analysis.

# %% [markdown]
# 2. Chapter 1 of "Thinking Clearly with Data," titled " Thinking Clearly in a Data-Driven Age," establishes that data and evidence are ubiquitous in modern society, making foundational quantitative reasoning a fundamental responsibility for every educated person and citizen. The chapter emphasises conceptual understanding—the "what" and "why"—over memorisation of formulas, aiming to cultivate critical thinking abilities and a deep understanding of the subject matter.
#
#     A central theme is that thinking and data are complements, not substitutes, warning that quantitative skills without clear thinking can be dangerous. It highlights that even well-trained people often make crucial errors with data, and initial intuitions can be misleading, maintaining scepticism.
#
#     The chapter provides cautionary tales, such as Abe's hasty diagnosis, demonstrating how easily diagnostic tests can be misinterpreted without a clear grasp of concepts like false positive rates. Examples like civil resistance and broken-windows policing further illustrate how misinterpreting correlations or overlooking factors like reversion to the mean can lead to flawed conclusions and poor decisions.
#
#     Ultimately, the chapter aims to help readers learn principles of clear thinking to spot common mistakes in evidence interpretation and make better decisions in their lives.

# %% [markdown]
# ---
# ## Part 5. Streamlit Setup and Test (10 points)
#
# 🗒️ **Task:** We will develop web apps using [Streamlit](https://streamlit.io) throughout the semester and your projects will use this tool.
#
# Install Streamlit on your computer, follow the installation guide: https://docs.streamlit.io/library/get-started/installation
#
# Note that Streamlit is run from the command line. [Read this.](https://docs.streamlit.io/get-started/fundamentals/main-concepts) Bookmark this documentation for later in the semester.
#
# Let us know if you have any issues with this.
#
# Next, create .py files with the following two codes and ensure that these run on your computer. It is not necessary that you understand what they do; the goal here is:
#
# ```python
# # Streamlit Code 1
#
# import streamlit as st
#
# st.write("Hello World!")
# ```
#
# ```python
# # Streamlit Code 2
#
# import streamlit as st
# import pandas as pd
# import numpy as np
#
# chart_data = pd.DataFrame(
#    np.random.randn(20, 3),
#    columns=['a', 'b', 'c'])
#
# st.line_chart(chart_data)
# ```
#
# 1. to get Streamlit operational on your computer, and let us know where the problems are,
# 2. and, see what Streamlit does and how it functions.
#
# Include screen shots to show that you got this to work.

# %% [markdown]
# ✏️ **Answer:** Put your screenshots here

# %% [markdown]
# streamlit run create.py
# ![image.png](attachment:cb98c9f8-aac7-40eb-b1af-34dd4542f574.png)

# %% [markdown]
# ---
# ## Congratulations, you're done!
#
# Submit this assignment by uploading your notebook to the course Desire2Learn web page.  Go to the "Homework" folder, find the appropriate submission link, and upload everything there. Make sure your name is on it!

# %% [markdown]
# &#169; Copyright 2023, Department of Computational Mathematics, Science and Engineering at Michigan State University.
